# %%
import nltk
import matplotlib.pyplot as plt
# download once only
#nltk.download()

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# The concordance function: shows every occurrence of a specific word.
text4.concordance("President")
# Out:
# Displaying 25 of 89 matches:
# artment it is made the duty of the President " to recommend to your considerati
# ecution of any official act of the President the Constitution requires an oath
# o taking upon myself the duties of President of the United States for another t
# he unequaled services of the first President , it was a common sentiment that t
# orrection is in the power of every President , and consequently in mine , it wo
# s would be found to constitute the President a part of the legislative power .
# ent have been entertained that the President , placed at the capital , in the c
# r conferring the veto power on the President . This argument acquires additiona
#  the nation ," as affording to the President sufficient authority for his consi
# to increase itself . By making the President the sole distributer of all the pa
#  declared it to be the duty of the President to see that the laws are executed
#  that the entire control which the President possesses over the officers who ha
# eference to their commissions by a President would be quite as effectual an arg
# titution making it the duty of the President to communicate information and aut
#  of a delicate character which the President is called upon to perform is the s
#  men who have filled the office of President of the United States even in the i
# ficial action he should not be the President of a part only , but of the whole
# portant functions intrusted to the President by the Constitution , and it may b
# The appointing power vested in the President imposes delicate and onerous dutie
# l faithfully execute the office of President of the United States and will to t
# e United States to be taken by the President " before he enters on the executio
#  since the first inauguration of a President under our National Constitution .
# having elected me to the office of President of the United States , I have , in
#  it their unreserved support . The President of the United States of necessity
# urated by my honored predecessor , President Grant , of submitting to arbitrati

# %%
# The similar function: find the words that are used in the same context as the selected word.
text4.similar("President")
# Out:
# nation people congress country government world constitution time
# union power peace states future executive way spirit land south means
# party

# %%
#The common_contexts function: looks at two or more words and gives you the contexts shared by those words. 
text4.common_contexts(["President", "country"])
# Out:
# the_to the_the the_of every_and the_a the_is the_by the_it of_and
# the_in a_we

# %%
#Dispersion plots: showing where specific words are located in a text in relation to other words. Each row is the text, while the lines on the plot show the location of the word for that row.
from IPython.display import display
plt.figure(figsize=(10, 8))
text4.dispersion_plot(["President", "country", "government", "constitution", "peace"])

# %%
#The set function: takes a variable and creates a unique list of the objects in it. All duplicates will be collapsed together (however, remember that spaces and punctuation can cause you issues - to be dealt with at a later time on how to clean up the data).
print(sorted(set(text3))[:50])
len(set(text3))
print(len(text4)) # to print the number of characters in the text.
# Out:
# 149797
# ['!', "'", '(', ')', ',', ',)', '.', '.)', ':', ';', ';)', '?', '?)', 'A', 'Abel', 'Abelmizraim', 'Abidah', 'Abide', 'Abimael', 'Abimelech', 'Abr', 'Abrah', 'Abraham', 'Abram', 'Accad', 'Achbor', 'Adah', 'Adam', 'Adbeel', 'Admah', 'Adullamite', 'After', 'Aholibamah', 'Ahuzzath', 'Ajah', 'Akan', 'All', 'Allonbachuth', 'Almighty', 'Almodad', 'Also', 'Alvah', 'Alvan', 'Am', 'Amal', 'Amalek', 'Amalekites', 'Ammon', 'Amorite', 'Amorites']
# 2789

# %%
#Lexical Richness: percent of the number of distinct words (types) is of the total word count.
len(set(text4)) / len(text4)
# Out:
# 0.06617622515804722

# %%
#The count function: allows you to count the number of times something has occurred.
text4.count("President")
# Out:
# 88

# %%
#The FreqDist function: creates a frequency distribution or a histogram of the frequency of each token in a text.
x = FreqDist(text4)
print(x)
#The most_common function: displays a set number of the most frequent tokens.
x.most_common(10)
# Out:
# <FreqDist with 9913 samples and 149797 outcomes>
# [('the', 9446),
#  ('of', 7087),
#  (',', 7045),
#  ('and', 5146),
#  ('.', 4856),
#  ('to', 4414),
#  ('in', 2561),
#  ('a', 2184),
#  ('our', 2021),
#  ('that', 1748)]

# %%
#The plot function: this function varies based on what you are doing, but here we are going to use it to make a cumulative frequency plot (rather than a histogram type frequency distribution).
plt.figure(figsize=(10, 8))
x.plot(50, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
plt.figure(figsize=(10, 8))
x.plot(50, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
#The hapaxes function: words that only appear once in the text.
x.hapaxes()[:10]
# Out:
# ['notification',
#  '14th',
#  'fondest',
#  'predilection',
#  'flattering',
#  'asylum',
#  'interruptions',
#  'awaken',
#  'distrustful',
#  'despondence']

# %%
lst = set(text4)
y = [word for word in lst if len(word) > 10 and word.__contains__("a")]
y
# Out:
# ['diversification',
#  'examination',
#  'understandings',
#  'Information',
#  'humiliating',
#  'consolidated',
#  'indispensable',
#  'establishing',
#  'concentration',
#  'rehabilitated',
#  'communicate',
#  'inculcating',
#  'Commonwealth',
#  'irrevocably',
#  'remunerating',
#  'earnestness',
#  'elimination',
#  'participate',
#  'immigration',
#  'magnificently',
#  'subordination',
#  'politicians',
#  'accommodation',
#  'Congressional',
#  'imponderable',
#  'intolerable',
#  'aspirations',
#  'appreciated',
#  'designation',
#  'antagonistic',
#  'particularity',
#  'preparations',
#  'extraordinary',
#  'insuperable',
#  'fortifications',
#  'particulars',
#  'familiarity',
#  'formulating',
#  'remuneration',
#  'criminality',
#  'contemplation',
#  'ratification',
#  'disagreements',
#  'investigate',
#  'transferring',
#  'Pennsylvania',
#  'fortunately',
#  'energetically',
#  'simplification',
#  'extenuating',
#  'fluctuation',
#  'influential',
#  'approximated',
#  'intentional',
#  'confederated',
#  'deprivation',
#  'antiphilosophists',
#  'reciprocated',
#  'watchfulness',
#  'inconsiderate',
#  'unification',
#  'indignantly',
#  'disarmament',
#  'limitations',
#  'uneconomical',
#  'impregnable',
#  'declarations',
#  'complicated',
#  'restoration',
#  'individuals',
#  'adjustments',
#  'uncontrollable',
#  'untarnished',
#  'unpatriotic',
#  'measureless',
#  'indispensably',
#  'inconsiderable',
#  'demilitarize',
#  'invigorated',
#  'entertaining',
#  'Republicans',
#  'advancement',
#  'authorities',
#  'comparatively',
#  'philanthropist',
#  'taxgatherer',
#  'probability',
#  'compensations',
#  'benefactors',
#  'inseparable',
#  'temporarily',
#  'inevitability',
#  'Contemplating',
#  'uncomplaining',
#  'unhesitatingly',
#  'vindication',
#  'voluntarily',
#  'disadvantaged',
#  'unauthorized',
#  'desperation',
#  'reformation',
#  'participants',
#  'unstoppable',
#  'unquestionable',
#  'dictatorship',
#  'constitutionally',
#  'affirmation',
#  'irredeemable',
#  'Scandinavia',
#  'disappointed',
#  'disaffection',
#  'accomplishing',
#  'termination',
#  'accountable',
#  'dramatically',
#  'enslavement',
#  'discriminating',
#  'unexplained',
#  'Inauguration',
#  'consolidate',
#  'legislatures',
#  'postulations',
#  'transcending',
#  'countenance',
#  'indignation',
#  'Bicentennial',
#  'characterized',
#  'intrinsically',
#  'continually',
#  'dispassionate',
#  'notification',
#  'expectation',
#  'unpreparedness',
#  'readjustment',
#  'insurmountable',
#  'disqualification',
#  'unalienable',
#  'aggregations',
#  'importunate',
#  'collaborator',
#  'adventurers',
#  'contemplated',
#  'illustrated',
#  'speculative',
#  'augmentation',
#  'commonwealth',
#  'participation',
#  'inattention',
#  'harmoniously',
#  'technological',
#  'information',
#  'demonstrations',
#  'ratifications',
#  'disappearing',
#  'conventional',
#  'Restoration',
#  'characteristic',
#  'unquestionably',
#  'sanctimonious',
#  'unfortunate',
#  'legislators',
#  'inhabitants',
#  'consideration',
#  'subordinate',
#  'nationalistic',
#  'Administration',
#  'vulnerability',
#  'consecrated',
#  'inconsiderately',
#  'retaliation',
#  'declaration',
#  'inspiration',
#  'segregation',
#  'International',
#  'Sectionalism',
#  'revolutionary',
#  'enumeration',
#  'associations',
#  'Corporations',
#  'commonplace',
#  'participating',
#  'undertaking',
#  'renunciation',
#  'overestimated',
#  'unfortunately',
#  'entanglement',
#  'accomplishments',
#  'Philadelphia',
#  'application',
#  'negotiations',
#  'disturbances',
#  'Commendable',
#  'counteraction',
#  'confrontation',
#  'anticipation',
#  'hypercritical',
#  'exhaustless',
#  'deliberating',
#  'threatening',
#  'agriculturists',
#  'schoolmaster',
#  'recommendations',
#  'confederacies',
#  'unanswerably',
#  'animosities',
#  'transportation',
#  'communications',
#  'bimetallism',
#  'attributable',
#  'watercourses',
#  'forefathers',
#  'maintenance',
#  'stimulating',
#  'incapacities',
#  'constrained',
#  'departments',
#  'reconsideration',
#  'speculators',
#  'contemplating',
#  'encroachments',
#  'imperialism',
#  'disorganization',
#  'embarrassing',
#  'dissatisfied',
#  'curtailment',
#  'appropriations',
#  'rehabilitation',
#  'deliberations',
#  'appreciating',
#  'disgraceful',
#  'demonstration',
#  'overestimate',
#  'adversaries',
#  'insignificance',
#  'perpetuation',
#  'incompatible',
#  'misrepresentation',
#  'considerably',
#  'safeguarding',
#  'anniversary',
#  'contemplations',
#  'achievement',
#  'contradistinction',
#  'sentimental',
#  'squandering',
#  'magnificence',
#  'undeviating',
#  'legislative',
#  'catastrophe',
#  'predominating',
#  'tribulation',
#  'conciliated',
#  'achievements',
#  'particularly',
#  'backgrounds',
#  'representative',
#  'cooperative',
#  'marginalized',
#  'stewardship',
#  'imperishable',
#  'characterize',
#  'pleasantness',
#  'speculation',
#  'admonitions',
#  'unreasonable',
#  'republicanism',
#  'transactions',
#  'Federalists',
#  'anticipated',
#  'publications',
#  'necessaries',
#  'satisfactorily',
#  'arraignment',
#  'Legislation',
#  'establishes',
#  'tranquillity',
#  'destination',
#  'incalculable',
#  'attainments',
#  'lawlessness',
#  'extermination',
#  'disinclination',
#  'consummating',
#  'inviolability',
#  'representation',
#  'astonishing',
#  'cooperating',
#  'circumstance',
#  'sympathized',
#  'sustainable',
#  'unexceptionable',
#  'pacification',
#  'instrumentality',
#  'centennials',
#  'reannexation',
#  'unessential',
#  'copartnership',
#  'Inconsiderable',
#  'Mediterranean',
#  'approximate',
#  'invitations',
#  'appropriate',
#  'emphatically',
#  'manufactured',
#  'denominations',
#  'observation',
#  'geographical',
#  'multiplication',
#  'provincials',
#  'reestablish',
#  'appreciative',
#  'slaveholding',
#  'disorganizing',
#  'internationality',
#  'calculations',
#  'representatives',
#  'calculating',
#  'overbalanced',
#  'technicalities',
#  'merchandise',
#  'adventurously',
#  'unrestrained',
#  'communicating',
#  'demoralizes',
#  'Confederacy',
#  'premeditation',
#  'apprehensions',
#  'usurpations',
#  'safeguarded',
#  'compassionate',
#  'reservation',
#  'Representative',
#  'fundamentally',
#  'civilization',
#  'militarists',
#  'configuration',
#  'restraining',
#  'Penetrating',
#  'naturalizing',
#  'disturbance',
#  'impartially',
#  'nationality',
#  'affirmations',
#  'overshadowed',
#  'qualifications',
#  'supplications',
#  'individually',
#  'association',
#  'reorganization',
#  'uncharitableness',
#  'practically',
#  'entanglements',
#  'frustration',
#  'translating',
#  'headsprings',
#  'increasingly',
#  'grandparents',
#  'Alleghanies',
#  'ascertaining',
#  'reestablished',
#  'accumulation',
#  'professionals',
#  'circulating',
#  'investigation',
#  'availability',
#  'dangerously',
#  'untrammeled',
#  'exhortations',
#  'incautiously',
#  'colonization',
#  'inheritance',
#  'determination',
#  'disregarded',
#  'regulations',
#  'unreasoning',
#  'emancipated',
#  'aggravation',
#  'relationships',
#  'comparative',
#  'transcended',
#  'practicable',
#  'reluctantly',
#  'considerable',
#  'unreasonably',
#  'educational',
#  'origination',
#  'manufactures',
#  'boastfulness',
#  'steadfastness',
#  'unfaltering',
#  'stimulation',
#  'unlawfulness',
#  'repudiation',
#  'arbitration',
#  'magistrates',
#  'Legislature',
#  'congratulations',
#  'depreciation',
#  'impracticable',
#  'inconceivable',
#  'unpracticed',
#  'deliberately',
#  'inauguration',
#  'liabilities',
#  'unprofitable',
#  'circulation',
#  'practicability',
#  'Arbitration',
#  'entertained',
#  'Afghanistan',
#  'devastation',
#  'discriminations',
#  'gratification',
#  'transcendent',
#  'continuation',
#  'ascertained',
#  'statesmanship',
#  'insurrectionary',
#  'purification',
#  'individuality',
#  'allegations',
#  'occupations',
#  'inalienable',
#  'deliverance',
#  'substantive',
#  'impassioned',
#  'unexaggerated',
#  'consequential',
#  'confederacy',
#  'impregnably',
#  'embarrassments',
#  'industrially',
#  'unceasingly',
#  'differentiating',
#  'organizations',
#  'inheritances',
#  'naturalization',
#  'felicitation',
#  'satisfaction',
#  'devastating',
#  'establishment',
#  'sentimentalizing',
#  'understands',
#  'communicated',
#  'outstanding',
#  'extravagance',
#  'exploitation',
#  'Declaration',
#  'cooperation',
#  'inextricably',
#  'contemplate',
#  'impartiality',
#  'calculation',
#  'encouragement',
#  'realization',
#  'acquisition',
#  'enfranchisement',
#  'congratulation',
#  'Guadalcanal',
#  'mountaineer',
#  'pusillanimous',
#  'solicitation',
#  'agriculture',
#  'disheartened',
#  'combination',
#  'encouraging',
#  'congratulate',
#  'administering',
#  'transcendently',
#  'appointment',
#  'discrepancy',
#  'exterminating',
#  'agricultural',
#  'attributing',
#  'immeasurably',
#  'proportionate',
#  'economically',
#  'incorporated',
#  'anticipating',
#  'modification',
#  'hardheartedness',
#  'reestablishment',
#  'conservation',
#  'enlargement',
#  'indiscriminate',
#  'unreclaimed',
#  'accommodations',
#  'instrumental',
#  'conspiracies',
#  'upbraidings',
#  'undauntedly',
#  'innumerable',
#  'corporation',
#  'consecrates',
#  'courageously',
#  'congregations',
#  'proliferation',
#  'antirepublican',
#  'commandments',
#  'inapplicable',
#  'temptations',
#  'universality',
#  'unfavorable',
#  'Departments',
#  'Superficial',
#  'exaggerated',
#  'uncertainty',
#  'Encouraging',
#  'satisfactions',
#  'mountaintop',
#  'antipathies',
#  'representations',
#  'considerately',
#  'effectually',
#  'Appreciating',
#  'unnecessary',
#  'acknowledged',
#  'legislation',
#  'amalgamated',
#  'appointments',
#  'practicality',
#  'conservative',
#  'administrated',
#  'arrangement',
#  'qualification',
#  'Subordinate',
#  'consecration',
#  'degeneration',
#  'manifesting',
#  'accomplishment',
#  'investigations',
#  'embarrassment',
#  'Congressman',
#  'conformable',
#  'concentrating',
#  'accompanied',
#  'legislature',
#  'unparalleled',
#  'aristocracy',
#  'confederate',
#  'grandchildren',
#  'importation',
#  'democracies',
#  'precipitate',
#  'unavoidable',
#  'recommendation',
#  'appropriateness',
#  'reconsecrate',
#  'continuance',
#  'unconquerable',
#  'misunderstanding',
#  'peacefullyâ',
#  'entrepreneurial',
#  'embarrassed',
#  'prostration',
#  'extravagant',
#  'reclamation',
#  'hospitality',
#  'substantially',
#  'emancipation',
#  'inessential',
#  'naturalized',
#  'transmitted',
#  'politically',
#  'Association',
#  'republicans',
#  'experimentation',
#  'reformations',
#  'disfranchised',
#  'justification',
#  'undertakings',
#  'dishonorable',
#  'discountenanced',
#  'Territorial',
#  'inaugurated',
#  'confederation',
#  'indications',
#  'demoralizing',
#  'eradication',
#  'promulgation',
#  'expectations',
#  'preservation',
#  'dispensations',
#  'unspeakable',
#  'appropriately',
#  'prerogative',
#  'demonstrate',
#  'perpetuating',
#  'acquisitions',
#  'preoccupations',
#  'discretionary',
#  'unequivocal',
#  'artificially',
#  'governmental',
#  'acknowledging',
#  'paternalism',
#  'battlefield',
#  'speculations',
#  'compensated',
#  'guardianship',
#  'affectionate',
#  'partialities',
#  'alternative',
#  'unmistakable',
#  'accountability',
#  'magnanimous',
#  'passionately',
#  'inhospitable',
#  'Establishment',
#  'exhortation',
#  'international',
#  'sanctioning',
#  'Massachusetts',
#  'imperatively',
#  'manufacturers',
#  'supplication',
#  'observations',
#  'degradation',
#  'consolatory',
#  'discharging',
#  'descendants',
#  'Fortunately',
#  'forbearance',
#  'approbation',
#  'auxiliaries',
#  'consultations',
#  'immeasurable',
#  'concentrated',
#  'obliteration',
#  'presidential',
#  'realistically',
#  'depositaries',
#  'inexhaustible',
#  'hearthstone',
#  'propagating',
#  'unsubstantial',
#  'consolation',
#  'initiatives',
#  'administrative',
#  'understandable',
#  'heartburnings',
#  'necessarily',
#  'significantly',
#  'humiliations',
#  'bipartisanship',
#  'supplicating',
#  'Politicians',
#  'originating',
#  'deteriorate',
#  'inescapably',
#  'advantageously',
#  'antifederal',
#  'Notwithstanding',
#  'archipelago',
#  'reconciliation',
#  'negotiation',
#  'encroaching',
#  'disapproved',
#  'Americanism',
#  'appeasement',
#  'anticipations',
#  'considerations',
#  'articulated',
#  'exceptional',
#  'conservator',
#  'inexcusable',
#  'Wastefulness',
#  'disorganize',
#  'administration',
#  'intellectual',
#  'functionaries',
#  'transcontinental',
#  'appropriation',
#  'recriminations',
#  'imagination',
#  'performance',
#  'workmanship',
#  'arrangements',
#  'southeastern',
#  'slaughtering',
#  'approaching',
#  'manifestation',
#  'patriotically',
#  'irrevocable',
#  'Abandonment',
#  'authorizing',
#  'corporations',
#  'abstractions',
#  'enthusiastically',
#  'buccaneering',
#  'transferred',
#  'mortifications',
#  'demoralization',
#  'celebration',
#  'respectable',
#  'unwarrantable',
#  'facilitating',
#  'altercation',
#  'administrations',
#  'accordingly',
#  'providential',
#  'maintaining',
#  'understanding',
#  'jeopardized',
#  'universally',
#  'sympathetic',
#  'importantly',
#  'annihilation',
#  'communication',
#  'misappropriation',
#  'contraction',
#  'transported',
#  'degradations',
#  'organization',
#  'constellation',
#  'apprehension',
#  'accumulated',
#  'Christianity',
#  'unsurpassed',
#  'furtherance',
#  'industrialism',
#  'specialized',
#  'foundations',
#  'sacrificing',
#  'battlefields',
#  'established',
#  'specifically',
#  'dissemination',
#  'intolerance',
#  'Communications',
#  'insignificant',
#  'encyclopedia',
#  'misunderstand',
#  'commensurate',
#  'Representatives',
#  'arbitrament',
#  'obligations',
#  'Administrations',
#  'appreciation',
#  'individualists',
#  'impenetrable',
#  'triumphantly',
#  'overbalance',
#  'discouragement',
#  'determinations',
#  'rectification',
#  'abandonment',
#  'manifestations',
#  'computation',
#  'incomparably',
#  'inspirations',
#  'administrators',
#  'administered',
#  'transaction',
#  'reservations',
#  'contracting',
#  'auspiciously',
#  'Confederation',
#  'formulation',
#  'Presidential',
#  'territorial',
#  'proclamation',
#  'remembrance',
#  'fundamental',
#  'commiseration',
#  'inadmissible',
#  'ambassadors',
#  'Revolutionary',
#  'acknowledge',
#  'drastically',
#  'hardworking',
#  'heartstrings',
#  'satisfactory',
#  'Discouraging',
#  'exasperated',
#  'prodigality',
#  'ineffectual',
#  'circumstances',
#  'periodically',
#  'expeditionary',
#  'discountenancing',
#  'acquaintance',
#  'proclaiming',
#  'essentially',
#  'Occasionally',
#  'demonstrated',
#  'complications',
#  'magnanimity',
#  'preparatory',
#  'aggrandizement',
#  'affiliation',
#  'exportation',
#  'spiritually',
#  'spirituality',
#  'infrastructure',
#  'clarification',
#  'permanently',
#  'disappointment',
#  'intricacies',
#  'substantial',
#  'insurrectional',
#  'reassurance',
#  'discriminate',
#  'dissipation',
#  'disappeared',
#  'stipulations',
#  'partisanship',
#  'involuntary',
#  'exasperation',
#  'cultivation',
#  'consummation',
#  'instantaneously',
#  'acknowledgment',
#  'authoritative',
#  'manufacturer',
#  'inestimable',
#  'unconstitutional',
#  'occasionally',
#  'justiciable',
#  'industrialists',
#  'cosmopolitan',
#  'Constitutional',
#  'apprehensive',
#  'insinuation',
#  'manufacturing',
#  'constitutional',
#  'propagation',
#  'deliberation',
#  'interoceanic',
#  'immediately',
#  'preparation',
#  'monarchical',
#  'reaffirming',
#  'complaining',
#  'advantageous',
#  'considerate',
#  'repartition',
#  'unavoidably',
#  'counteracted',
#  'languishing',
#  'generations',
#  'implication',
#  'exhilarated',
#  'traditional',
#  'ecclesiastical',
#  'conciliation',
#  'establishments',
#  'unaccounted',
#  'magnificent',
#  'perseverance',
#  'relationship',
#  'accomplished',
#  'precautions',
#  'inclination',
#  'attachments',
#  'domiciliary',
#  'explanation',
#  'exceptionalâ',
#  'arbitrarily',
#  'nonpartisan',
#  'combinations',
#  'legitimately',
#  'interpretation',
#  'engagements',
#  'illuminated',
#  'significant',
#  'compensation',
#  'discrimination',
#  'feasibility',
#  'justifiable',
#  'totalitarian',
#  'acquiescence',
#  'instrumentalities',
#  'humiliation',
#  'sectionalism']

# %%
#Collocations: Sequence of words that occurs together often.
#Bigrams: (or n-grams) n-words that occur together, so a bigram are two words that occur together like peanut butter.
#bigrams(text you want to work with) - helps if you put the list() function around it to convert it to something workable with python.
list(bigrams(['more', 'is', 'said', 'than', 'done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
#The collocations function: shows frequent bigrams (default), ignoring stop words.
text4.collocations(num = 10)
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice

# %%
fdist = FreqDist(len(w) for w in text4)
fdist
# Out:
# FreqDist({3: 29249, 2: 27744, 4: 18779, 1: 16800, 5: 13292, 6: 10882, 7: 10134, 8: 7364, 9: 5715, 10: 4784, ...})

# %%
#The freq function: shows you the frequency of selected item.
print(fdist.freq(3))
# Out:
# 0.19525758192754195

# %%
plt.figure(figsize=(10, 8))
fdist.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
